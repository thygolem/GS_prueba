# %%
import pandas as pd
import numpy as np

# %%
gs = pd.read_csv("IgnitionPrueba.csv", sep=",")

gs.head()
# Out:
# c:\Users\thygo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,2,3,4,5,6,7,8,10,11,12,14,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      DOW         Time Bay 1\Chiller Status Bay 1\Temperature Bay 1\Humidity  \
# 0  Int32       String                Int32             Float          Float
# 1      1  12:00:00 AM                    1                50             10
# 2      1  12:00:10 AM                    2            49.017          9.045
# 3      1  12:00:20 AM                    2            48.551          8.538
# 4      1  12:00:30 AM                    1            49.523          8.208
#
#   Bay 1\Power Draw Bay 2\Chiller Status Bay 2\Temperature Bay 2\Humidity  \
# 0            Float                Int32             Float          Float
# 1                0                    2                50             10
# ...

# %%
time = gs['Time']
status = gs['Bay 1\\Chiller Status']
temp = gs['Bay 1\\Chiller Temp']
